# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
film= pd.read_excel('data movies.xlsx')

# %%
film
# Out:
#     Rank                    Title      Genre  Year  Runtime_Minutes  Rating  \
# 0      1  Guardians of the Galaxy     Action  2014              121     8.1
# 1      2               Prometheus  Adventure  2012              124     7.0
# 2      3                    Split     Horror  2016              117     7.3
# 3      4                     Sing     Comedy  2016              108     7.2
# 4      5            Suicide Squad     Action  2016              123     6.2
# ..   ...                      ...        ...   ...              ...     ...
# 95   116   Office Christmas Party     Comedy  2016              105     5.8
# 96   117           The Neon Demon     Horror  2016              118     6.2
# 97   118                   Dangal     Action  2016              161     8.8
# 98   119      10 Cloverfield Lane      Drama  2016              104     7.2
# 99   120             Finding Dory     Comedy  2016               97     7.4
#
#      Votes  Revenue_Millions  Meta_Score
# ...

# %%
len(film)
# Out:
# 100

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              100 non-null    int64
#  1   Title             100 non-null    object
#  2   Genre             100 non-null    object
#  3   Year              100 non-null    int64
#  4   Runtime_Minutes   100 non-null    int64
#  5   Rating            100 non-null    float64
#  6   Votes             100 non-null    int64
#  7   Revenue_Millions  100 non-null    float64
#  8   Meta_Score        99 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#              Rank         Year  Runtime_Minutes     Rating         Votes  \
# count  100.000000   100.000000       100.000000  100.00000  1.000000e+02
# mean    59.800000  2015.060000       121.290000    7.18400  2.637305e+05
# std     35.204453     2.097714        19.280647    0.88463  3.170761e+05
# min      1.000000  2006.000000        87.000000    4.10000  2.790000e+02
# 25%     30.750000  2015.000000       108.000000    6.67500  5.006675e+04
# 50%     59.500000  2016.000000       118.000000    7.25000  1.363515e+05
# 75%     90.250000  2016.000000       132.250000    7.82500  3.414848e+05
# max    120.000000  2016.000000       187.000000    9.00000  1.791916e+06
#
#        Revenue_Millions  Meta_Score
# count        100.000000   99.000000
# mean         150.878500   63.030303
# std          179.966394   16.198044
# min            0.010000   18.000000
# 25%           29.725000   52.000000
# 50%           87.705000   66.000000
# 75%          193.640000   74.500000
# ...

# %%
film.Title = film.Title.astype('category')

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              100 non-null    int64
#  1   Title             100 non-null    category
#  2   Genre             100 non-null    object
#  3   Year              100 non-null    int64
#  4   Runtime_Minutes   100 non-null    int64
#  5   Rating            100 non-null    float64
#  6   Votes             100 non-null    int64
#  7   Revenue_Millions  100 non-null    float64
#  8   Meta_Score        99 non-null     float64
# dtypes: category(1), float64(3), int64(4), object(1)
# memory usage: 12.3+ KB

# %%
film.Genre = film.Genre.astype('category')
film.Year = film.Year.astype('category')

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              100 non-null    int64
#  1   Title             100 non-null    category
#  2   Genre             100 non-null    category
#  3   Year              100 non-null    category
#  4   Runtime_Minutes   100 non-null    int64
#  5   Rating            100 non-null    float64
#  6   Votes             100 non-null    int64
#  7   Revenue_Millions  100 non-null    float64
#  8   Meta_Score        99 non-null     float64
# dtypes: category(3), float64(3), int64(3)
# memory usage: 11.7 KB

# %%
film.Genre.unique()
# Out:
# [Action, Adventure, Horror, Comedy, Drama, History, Crime, Romance]
# Categories (8, object): [Action, Adventure, Horror, Comedy, Drama, History, Crime, Romance]

# %%
film.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Crime', 'Drama', 'History', 'Horror',
#        'Romance'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = 8 , 4

# %%
sns.set_style('darkgrid')
j = sns.jointplot(data = film, x = 'Rating',y="Votes", edgecolor ="black")

# %%
sns.set_style('darkgrid')
j = sns.jointplot(data = film, x = 'Rating',y="Votes", kind = 'hex')

# %%
ms=sns.distplot(film.Rating)

# %%
ms=plt.hist(film.Rating, bins = 20)

# %%
plt.hist(film.Votes)
plt.show()

# %%
film.Genre == 'Drama'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98     True
# 99    False
# Name: Genre, Length: 100, dtype: bool

# %%
film[film.Genre == 'Drama']
# Out:
#     Rank                  Title  Genre  Year  Runtime_Minutes  Rating   Votes  \
# 10    12         Hidden Figures  Drama  2016              127     7.8   93103
# 13    15               Colossal  Drama  2016              109     6.4    8612
# 15    17          Hacksaw Ridge  Drama  2016              139     8.2  211760
# 17    19                   Lion  Drama  2016              118     8.1  102061
# 18    20                Arrival  Drama  2016              116     8.0  340798
# 20    22  Manchester by the Sea  Drama  2016              137     7.9  134213
# 23    29               Bad Moms  Drama  2016              100     6.2   66540
# 26    32      Nocturnal Animals  Drama  2016              116     7.5  126030
# 35    42              Moonlight  Drama  2016              111     7.5  135095
# 37    45              Lowriders  Drama  2016               99     6.3     279
# 39    47            Miss Sloane  Drama  2016              132     7.3   17818
# ...

# %%
film.Genre.value_counts()
# Out:
# Action       26
# Drama        25
# Adventure    19
# Comedy       10
# Crime         9
# Horror        5
# Romance       3
# History       3
# Name: Genre, dtype: int64

# %%
film[film.Genre == 'Action'].Revenue_Millions
# Out:
# 0     333.13
# 4     325.02
# 5      45.13
# 7       8.01
# 16    162.16
# 22    103.14
# 24     54.65
# 27    155.33
# 28    363.02
# 32    232.60
# 40    158.80
# 42     30.35
# 45    533.32
# 51    330.25
# 57    153.63
# 59     61.28
# 60     40.07
# 64    623.28
# 65    128.34
# 79    458.99
# 80     36.25
# 85    181.02
# 87     45.43
# 90    126.59
# 93    210.59
# 97     11.15
# Name: Revenue_Millions, dtype: float64

# %%
plt.hist(film[film.Genre == 'Drama'].Revenue_Millions)
plt.show()

# %%
plt.hist(film[film.Genre == 'Action'].Revenue_Millions)
plt.hist(film[film.Genre == 'Drama'].Revenue_Millions)
plt.hist(film[film.Genre == 'Comedy'].Revenue_Millions)
plt.show()

# %%
film.Genre.value_counts().idxmax()
# Out:
# 'Action'

# %%
plt.hist([film[film.Genre == 'Action'].Revenue_Millions,\
         film[film.Genre == 'Drama'].Revenue_Millions], \
         bins =15, stacked = True)
plt.show()

# %%
for gen in film.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Crime
# Drama
# History
# Horror
# Romance

# %%
list1 = list()
for gen in film.Genre.cat.categories:
    list1.append(film[film.Genre == gen].Revenue_Millions)

# %%
print(list1)
# Out:
# [0     333.13
# 4     325.02
# 5      45.13
# 7       8.01
# 16    162.16
# 22    103.14
# 24     54.65
# 27    155.33
# 28    363.02
# 32    232.60
# 40    158.80
# 42     30.35
# 45    533.32
# 51    330.25
# 57    153.63
# 59     61.28
# 60     40.07
# 64    623.28
# 65    128.34
# 79    458.99
# 80     36.25
# 85    181.02
# 87     45.43
# 90    126.59
# 93    210.59
# 97     11.15
# Name: Revenue_Millions, dtype: float64, 1     126.46
# 8     100.01
# 9     234.02
# 11    532.17
# 19      7.22
# 21    153.69
# 30    408.08
# 31    187.99
# 33     93.38
# 38    241.06
# 41    936.63
# 55    128.25
# 63    341.26
# 66    292.57
# 70    652.18
# 72    760.51
# 76     47.17
# 86    228.43
# 94    380.96
# Name: Revenue_Millions, dtype: float64, 3     270.32
# 6     151.06
# 12    248.75
# 14    368.31
# 25     60.31
# 34     97.66
# 67      5.88
# 89      1.66
# 95     54.73
# 99    486.29
# Name: Revenue_Millions, dtype: float64, 44     43.00
# 47     89.21
# 52     75.31
# ...

# %%
h = plt.hist(list1, bins = 5)

# %%
h = plt.hist(list1, bins = 20, stacked = True, edgecolor = 'black')

# %%
import  numpy as np

# %%
film[film.Genre == 'Action'].Revenue_Millions.mean()
# Out:
# 188.90500000000003

# %%
list1 = list()
mylabels = list()
for gen in film.Genre.cat.categories:
    list1.append(film[film.Genre == gen].Revenue_Millions)
    mylabels.append(gen)
plt.hist(list1,bins =15, stacked =True, label = mylabels, edgecolor = 'black')
plt.legend()
plt.show()

# %%
visl = sns.lmplot(data = film, x ="Rating", y = "Revenue_Millions", \
                  fit_reg =True, hue ='Genre',  size =6, aspect=1)

# %%
# Kdeplot
kd1 = sns.kdeplot(film.Rating, film.Revenue_Millions)

# %%
kd1 = sns.kdeplot(film.Rating, film.Revenue_Millions,shade =True)

# %%
kd1 = sns.kdeplot(film.Rating, film.Revenue_Millions,shade =True, shade_lowest=False)

# %%
sns.set_style("darkgrid")
kd1 = sns.kdeplot(film.Rating, film.Revenue_Millions,\
                  shade =True, cmap ="Reds",shade_lowest=False)

# %%
#Dashboard
a, b =  plt.subplots(2,2, figsize = (12,6))
kd1 = sns.violinplot(data.Rating, data.Revenue_Millions, ax=b[1, 1])
kd2 = sns.kdeplot(data.Rating, data.Votes,shade =False,ax=b[0, 0])
kd3 = sns.scatterplot(x = data.Rating,y= data.Votes,  ax=b[1, 0])
kd4 = sns.boxplot(data.Rating, data.Runtime_Minutes, ax=b[0, 1])

# %%
# subplot, kdeplot
a, b= plt.subplots(2,2, figsize = (12,6))

kd1 = sns.kdeplot(film.Rating, \
 film.Revenue_Millions,cmap ="Reds",shade = False,ax = b[0,0])

kd2 = sns.kdeplot(film.Rating, \
 film.Votes, shade =False,cmap ="inferno", ax = b[0,1])

kd3 = sns.kdeplot(film.Rating,\
 film.Revenue_Millions,shade =False, cmap ="gist_gray", ax=b[1,0])

kd2 = sns.kdeplot(film.Rating, \
 film.Votes,shade =True,cmap ="summer", ax=b[1,1])

# %%
# subplot, kdeplot
a, b= plt.subplots(2,2, figsize = (12,6))

kd1 = sns.kdeplot(film.Rating,\
   film.Revenue_Millions,shade =False,shade_lowest=True,cmap ="Reds",ax=b[0,0])

kd2 = sns.kdeplot(film.Rating, \
  film.Votes,shade =False,shade_lowest=False,cmap ="gist_gray", ax = b[0,1])

kd3 = sns.kdeplot(film.Rating, \
    film.Revenue_Millions,shade =True,shade_lowest=True, cmap ="inferno", ax=b[1,0])

kd2 = sns.kdeplot(film.Rating, \
     film.Votes,shade =True,shade_lowest=False,cmap ="summer", ax=b[1,1])

# %%
# subplot, kdeplot
a, b= plt.subplots(1,2, figsize = (12,6))
kd1 = sns.kdeplot(film.Rating, \
                  film.Revenue_Millions,shade =False,ax=b[0])
kd2 = sns.kdeplot(film.Rating, \
                  film.Votes,shade =False, ax = b[1])

# %%
# violin plot
z = sns.violinplot(data = film, x = "Genre", y ="Meta_Score")

# %%
#Boxplot
z = sns.boxplot(data = film, x = "Genre", y ="Meta_Score")
